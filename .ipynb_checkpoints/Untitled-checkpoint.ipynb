# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_excel("TACs.xlsx", sheet_name=None)
relevant_keys = ['PT 300 ml Qclear 2', 'PT 300 ml Qclear 1', 'PT 200 ml Qclear 2', 'PT 200 ml Qclear 1', 'PT 100 ml Qclear 2', 'PT 100 ml Qclear 1']
qclear = [2, 1, 2, 1, 2, 1]
sizes = [300, 300, 200, 200, 100, 100]

# %%
# Out:
# [300, 300, 200, 200, 200, 100, 100]

# %%
frames = []
for key, clear, size in zip(relevant_keys, qclear, sizes):
    print(clear, size)
    frame = data[key]
    df = frame.loc[5:]
    df.columns = ["time", "input", "tissue"]
    df[['time_start', 'time_end']] = df['time'].str.split(' - ', 1, expand=True)
    df["qclear"] = clear
    df["size"] = size
    df = df.astype({'input': 'float64', 'tissue': 'float64', 'time_start': 'int32', 'time_end': 'int32'})
    df = df.drop(["time"], axis=1)
    frames.append(df)
df = pd.concat(frames)
# Out:
# 2 300
# 1 300
# 2 200
# 1 200
# 2 100
# 1 100
# /home/mikael/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /home/mikael/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/mikael/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df
# Out:
#            input        tissue  time_start  time_end  qclear  size
# 5   1.456478e+03     407.96191           0         5       2   300
# 6   1.278932e+03     459.05683           5        10       2   300
# 7   2.265328e+04     646.44457          10        15       2   300
# 8   4.574733e+05   10505.08901          15        20       2   300
# 9   1.643083e+06   89934.22971          20        25       2   300
# ..           ...           ...         ...       ...     ...   ...
# 24  1.392625e+06  784895.39999         140       160       1   100
# 25  6.902623e+05  925024.12368         160       190       1   100
# 26  2.563172e+05  870937.93689         190       220       1   100
# 27  7.789175e+04  634442.87209         220       250       1   100
# 28  2.397860e+04  369306.60994         250       280       1   100
#
# [144 rows x 6 columns]

# %%
df.groupby(['qclear', 'size']).size()
# Out:
# qclear  size
# 1       100     24
#         200     24
#         300     24
# 2       100     24
#         200     24
#         300     24
# dtype: int64

# %%
for name, group in df.groupby(['qclear', 'size']):
    print(f"QCLEAR: {group['qclear'].iloc[1]}, SIZE: {group['size'].iloc[1]} ml")
    plt.plot(group["time_start"], group["tissue"], color="b")
    plt.plot(group["time_start"], group["input"], color="r")
    plt.show()
# Out:
# QCLEAR: 1, SIZE: 100 ml
# QCLEAR: 1, SIZE: 200 ml
# QCLEAR: 1, SIZE: 300 ml
# QCLEAR: 2, SIZE: 100 ml
# QCLEAR: 2, SIZE: 200 ml
# QCLEAR: 2, SIZE: 300 ml

# %% [markdown]
# Selkeästi SIZE vaikuttaa suuresti tissuen jakaumaan. Mitä suurempi size sitä "lyhyempi" jakauma

# %%
for name, group in df.groupby(['qclear', 'size']):
    #plt.plot(group["input"], group["tissue"], color="b")
    plt.plot(group["time_start"], group["tissue"] - group["input"])
    plt.show()
